# %% [markdown]
# ## Install Requirements

# %%
# !apt update
# !apt upgrade
# !apt install gdal-bin python-gdal python3-gdal

# %% [markdown]
# ## Mount gDrive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Folder Paths

# %%
# IMAGE_FOLDER_ID = "1dNrhrHBgfBgCcNzzrn-Kf6xAKxrPhnwl"
# TEMPT_FOLDER_ID = "1bGHeob3mTuPVswoXfaSph9OKhf2cLJG8"
# MASKS_FOLDER_ID = "1bWeAOvdLI-e_8l6fENUibImTnRbVsGB5"

HOME_DIR_PATH = "/content/drive/My Drive/"

IMAGE_FOLDER_PATH = HOME_DIR_PATH + "CropYield/MOD09A1_2003_2018/"
TEMPT_FOLDER_PATH = HOME_DIR_PATH + "CropYield/MYD11A2_2003_2018/"
MASKS_FOLDER_PATH = HOME_DIR_PATH + "CropYield/MCD12Q1_2003_2018/"

SOYBEANS_DATA_PATH = HOME_DIR_PATH + "CropYield/NASS_Soybeans_2003_2018.csv"

SAVE_DIR_PATH = HOME_DIR_PATH + "CropYield/Processed_Images/"

# %%
from os import listdir
files_names = listdir(IMAGE_FOLDER_PATH)

# %% [markdown]
# ## Process Images

# %%
from pathlib import Path

import numpy  as np
import pandas as pd

import gdal
import math
from itertools import repeat
from concurrent.futures import ProcessPoolExecutor

class ProcessImages:
    """
    Take the exported, downloaded data and clean it.

    Specifically,
    - split the image collections into years
    - merge the bands from temperature and images into one file
    - apply the mask so that only cropland is considered

    Parameters
    -----------
    image_path: 
        path to which the image tif files have been saved
    tempt_path: 
        path to which the temperature tif files have been saved
    masks_path: 
        path to which the mask tif files have been saved
    yield_data: 
        path to the yield data csv file
    save_dir: 
        path to save the data to
    multiprocessing: 
        boolean for whether to use multiprocessing
    """
    def __init__(self, image_path, tempt_path, masks_path, yield_path, save_dir, 
                 multiprocessing=True):
        
        self.image_path = Path(image_path)
        self.tempt_path = Path(tempt_path)
        self.masks_path = Path(masks_path)
        
        self.yield_path = Path(yield_path)
        self.save_dir   = Path(save_dir)
        
        self.tif_files  = listdir(image_path)[:]

        self.multiprocessing = False
        self.processes   = 4
        self.parallelism = 6

        self.save_dir   = Path(save_dir)
        if not self.save_dir.exists():
            self.save_dir.mkdir()

        self.yield_data = get_yield_data(yield_path)
        

    def process(self, num_years=16, delete_when_done=False):
        """
        Process all the data.

        Parameters
        ----------
        num_years:
            integer years of data to create.
        delete_when_done:
            boolean for whether or not to delete the original .tif files
        """
        if delete_when_done: print("Warning! .tif files will be deleted.")
            
        # Process images one-by-one.    
        if not self.multiprocessing:
            for filename in self.tif_files:
                process_county(
                    filename, self.save_dir, 
                    self.image_path, self.masks_path, self.tempt_path, self.yield_data, 
                    num_years=num_years, delete_when_done=delete_when_done
                )
        
        # Parallel process images.
        else:
            
            length     = len(self.tif_files)
            files_iter = iter(self.tif_files)

            # Turn all other arguments to iterators.
            
            savedir_iter   = repeat(self.save_dir)
            im_path_iter   = repeat(self.image_path)
            mask_path_iter = repeat(self.massk_path)
            temp_path_iter = repeat(self.tempt_path)
            
            yield_iter     = repeat(self.yield_data)
            num_years_iter = repeat(num_years)
            
            delete_when_done_iter = repeat(delete_when_done)

            with ProcessPoolExecutor() as executor:
                chunksize = int(max(length / (self.processes * self.parallelism), 1))
                executor.map(process_county, 
                    files_iter, savedir_iter, 
                    im_path_iter, mask_path_iter, temp_path_iter, yield_iter, 
                    num_years_iter, delete_when_done_iter, chunksize=chunksize
                )

def get_yield_data(yield_path):
    """
    Cleans the yield data by making sure any Nan values in the columns we 
    care about are removed.
    """
    cols_nan = ['Year', 'State ANSI', 'County ANSI', 'Value']
    yield_values = pd.read_csv(yield_path).dropna(subset=cols_nan, how='any')
    cols_val = ['Year', 'State ANSI', 'County ANSI']
    return yield_values[cols_val].values
                
                
def process_county(filename, savedir, image_path, masks_path, tempt_path, yield_data, num_years,
                   delete_when_done):
    """
    Process and save county level data
    """

    # Files have "{state}_{county}.tif" format, the last 4 characters are ".tif".
    locations = filename[:-4].split("_")
    state, county = int(locations[0]), int(locations[1])

    image = np.transpose(
        np.array(gdal.Open(str(image_path / filename)).ReadAsArray(), dtype='uint16'),
        axes=(1, 2, 0)
    )

    tempt = np.transpose(
        np.array(gdal.Open(str(tempt_path / filename)).ReadAsArray(), dtype='uint16'),
        axes=(1, 2, 0)
    )

    masks = np.transpose(
        np.array(gdal.Open(str(masks_path / filename)).ReadAsArray(), dtype='uint16'),
        axes=(1, 2, 0)
    )
    
    # A value of 12 indicates cropland; everything else, we want to ignore
    masks[masks != 12] = 0
    masks[masks == 12] = 1

    # when exporting the image, we appended bands from many years into a single image for efficiency. We want
    # to split it back up now

    # num bands and composite period from the MODIS website
    image_list = divide_into_years(image, bands=7, composite_period=  8, num_years=num_years)
    tempt_list = divide_into_years(tempt, bands=2, composite_period=  8, num_years=num_years)
    masks_list = divide_into_years(masks, bands=1, composite_period=365, num_years=num_years, extend=True)

    image_tempt_merged = merge_image_lists(image_list, 7, tempt_list, 2)
    masked_image_tempt = mask_image(image_tempt_merged, masks_list)
    
    assert len(masked_image_tempt) == num_years, "Dataset does not align with given number of years."

    # start year from the MODIS website
    start_year = 2003  
    
    for i in range(0, num_years):
        year = i + start_year

        key = np.array([year, state, county])
        
        # Check if this key is in the yield data.
        if np.equal(yield_data[:, :3], key).all(axis=1).max():
            save_filename = f'{year}_{state}_{county}'
            np.save(savedir / save_filename, masked_image_tempt[i])
    
    # Delete .tif files if delete_when_done flag is set.
    if delete_when_done:
        (image_path / filename).unlink()
        (temperature_path / filename).unlink()
        (mask_path / filename).unlink()
        
    print(f'{filename} array written')


# helper methods for the data cleaning class

def divide_into_years(image, bands, composite_period, num_years=16, extend=False):
    """
    Parameters
    ----------
    image: the appended image collection to split up
    bands: the number of bands in an individual image
    composite_period: length of the composite period, in days
    num_years: how many years of data to create.
    extend: boolean, default=False
        If true, and num_years > number of years for which we have data, then the extend the image
        collection by copying over the last image.
        NOTE: This is different from the original code, where the 2nd to last image is copied over

    Returns:
    ----------
    im_list: a list of appended image collections, where each element in the list is a year's worth
        of data
    """
    bands_per_year = bands * math.ceil(365 / composite_period)

    # Pad the images with the last image if flag 'extend' is set.
    if extend:
        num_bands_necessary = bands_per_year * num_years
        while image.shape[2] < num_bands_necessary:
            image = np.concatenate((image, image[:, :, -bands:]), axis=2)

    image_list = []
    cur_idx = 0
    for i in range(0, num_years):
        image_list.append(image[:, :, cur_idx:cur_idx + bands_per_year])
        cur_idx += bands_per_year
        
    # image_list.append(img[:, :, cur_idx:])
    return image_list


def merge_image_lists(im_list_1, num_bands_1, im_list_2, num_bands_2):
    """
    Given two image lists (i.e. the MODIS images and the MODIS temperatures),
    merges them together.

    Parameters
    ----------
    im_list_1: the first image list to merge, where an image list is the output of
        divide_into_years. Note that im_list_1 and im_list_2 must be the same length
        (i.e. the num_years parameter in divide_into_years must be the same when both image
        lists are created)
    num_bands_1: int
        The number of bands in each image in im_list_1
    im_list_2: the second image list to merge, where an image list is the output of
        divide_into_years
    num_bands_2: int

    Returns
    ----------
    merged_im_list: A merged image list
    """
    merged_list = []

    assert len(im_list_1) == len(im_list_2), "Image lists are not the same length!"

    for im1, im2 in zip(im_list_1, im_list_2):
        individual_images = []

        # split the 'year' appended images into individual images
        for image_1, image_2 in zip(np.split(im1, im1.shape[-1] / num_bands_1, axis=-1),
                                    np.split(im2, im2.shape[-1] / num_bands_2, axis=-1)):
            individual_images.append(np.concatenate((image_1, image_2), axis=-1))
        merged_list.append(np.concatenate(individual_images, axis=-1))
    return merged_list


def mask_image(im_list, mask_list):
    masked_im_list = []

    assert len(im_list) == len(mask_list), "Mask and Image lists are not the same length!"

    for img, mask in zip(im_list, mask_list):
        expanded_mask = np.tile(mask, (1, 1, img.shape[2]))
        masked_img = img * expanded_mask
        masked_im_list.append(masked_img)

    return masked_im_list

# %%
process = ProcessImages(
    IMAGE_FOLDER_PATH, TEMPT_FOLDER_PATH, MASKS_FOLDER_PATH, 
    SOYBEANS_DATA_PATH, SAVE_DIR_PATH
)

# %%
process.process()
# Out:
# 1_47.tif array written
# 1_65.tif array written
# 1_85.tif array written
# 1_105.tif array written
# 1_119.tif array written
# 1_3.tif array written
# 1_53.tif array written
# 1_99.tif array written
# 1_9.tif array written
# 1_19.tif array written
# 1_43.tif array written
# 1_49.tif array written
# 1_55.tif array written
# 1_71.tif array written
# 1_33.tif array written
# 1_77.tif array written
# 1_79.tif array written
# 1_83.tif array written
# 1_89.tif array written
# 1_103.tif array written
# 1_21.tif array written
# 1_57.tif array written
# 1_121.tif array written
# 1_125.tif array written
# 1_5.tif array written
# 1_39.tif array written
# 1_61.tif array written
# 1_69.tif array written
# 1_109.tif array written
# 5_105.tif array written
# 5_1.tif array written
# 5_35.tif array written
# 5_37.tif array written
# 5_77.tif array written
# 5_85.tif array written
# 5_95.tif array written
# 5_107.tif array written
# 5_117.tif array written
# 5_123.tif array written
# 5_147.tif array written
# 5_21.tif array written
# 5_31.tif array written
# 5_55.tif array written
# 5_63.tif array written
# 5_67.tif array written
# 5_75.tif array written
# 5_93.tif array written
# 5_111.tif array written
# 5_121.tif array written
# 5_145.tif array written
# 5_7.tif array written
# 5_3.tif array written
# 5_17.tif array written
# 5_43.tif array written
# 5_41.tif array written
# 5_69.tif array written
# 5_79.tif array written
# 10_1.tif array written
# 10_3.tif array written
# 10_5.tif array written
# 13_91.tif array written
# 13_23.tif array written
# 13_175.tif array written
# 13_225.tif array written
# 13_33.tif array written
# 13_163.tif array written
# 13_165.tif array written
# 13_147.tif array written
# 13_221.tif array written
# 13_55.tif array written
# 13_129.tif array written
# 13_295.tif array written
# 13_19.tif array written
# 13_27.tif array written
# 13_69.tif array written
# 13_161.tif array written
# 13_71.tif array written
# 13_271.tif array written
# 13_1.tif array written
# 13_109.tif array written
# 13_277.tif array written
# 13_229.tif array written
# 13_279.tif array written
# 13_267.tif array written
# 13_299.tif array written
# 13_87.tif array written
# 13_99.tif array written
# 13_131.tif array written
# 13_205.tif array written
# 13_253.tif array written
# 13_273.tif array written
# 13_275.tif array written
# 13_193.tif array written
# 13_197.tif array written
# 13_269.tif array written
# 17_39.tif array written
# 17_107.tif array written
# 17_115.tif array written
# 17_123.tif array written
# 17_125.tif array written
# 17_113.tif array written
# 17_129.tif array written
# 17_175.tif array written
# 17_179.tif array written
# 17_203.tif array written
# 17_143.tif array written
# 17_19.tif array written
# 17_53.tif array written
# 17_75.tif array written
# 17_91.tif array written
# 17_105.tif array written
# 17_147.tif array written
# 17_183.tif array written
# 17_23.tif array written
# 17_25.tif array written
# 17_29.tif array written
# 17_33.tif array written
# 17_35.tif array written
# 17_41.tif array written
# 17_45.tif array written
# 17_49.tif array written
# 17_51.tif array written
# 17_79.tif array written
# 17_101.tif array written
# 17_139.tif array written
# 17_121.tif array written
# 17_159.tif array written
# 17_173.tif array written
# 17_7.tif array written
# 17_63.tif array written
# 17_37.tif array written
# 17_99.tif array written
# 17_89.tif array written
# 17_97.tif array written
# 17_111.tif array written
# 17_197.tif array written
# 17_11.tif array written
# 17_15.tif array written
# 17_73.tif array written
# 17_85.tif array written
# 17_103.tif array written
# 17_131.tif array written
# 17_141.tif array written
# 17_155.tif array written
# 17_161.tif array written
# 17_177.tif array written
# 17_201.tif array written
# 17_195.tif array written
# 17_55.tif array written
# 17_59.tif array written
# 17_69.tif array written
# 17_81.tif array written
# 17_151.tif array written
# 17_127.tif array written
# 17_185.tif array written
# 17_191.tif array written
# 17_193.tif array written
# 17_27.tif array written
# 17_87.tif array written
# 17_145.tif array written
# 17_153.tif array written
# 17_157.tif array written
# 17_133.tif array written
# 17_163.tif array written
# 17_189.tif array written
# 17_199.tif array written
# 17_9.tif array written
# 17_57.tif array written
# 17_67.tif array written
# 17_1.tif array written
# 17_71.tif array written
# 17_95.tif array written
# 17_109.tif array written
# 17_169.tif array written
# 17_187.tif array written
# 17_5.tif array written
# 17_13.tif array written
# 17_17.tif array written
# 21_57.tif array written
# 21_61.tif array written
# 21_85.tif array written
# 21_87.tif array written
# 21_93.tif array written
# 21_99.tif array written
# 21_123.tif array written
# 21_155.tif array written
# 21_163.tif array written
# 21_171.tif array written
# 21_169.tif array written
# 21_207.tif array written
# 21_179.tif array written
# 21_217.tif array written
# 21_227.tif array written
# 21_135.tif array written
# 21_89.tif array written
# 21_205.tif array written
# 21_199.tif array written
# 21_33.tif array written
# 21_231.tif array written
# 21_47.tif array written
# 21_55.tif array written
# 21_59.tif array written
# 21_91.tif array written
# 21_101.tif array written
# 21_149.tif array written
# 21_183.tif array written
# 21_213.tif array written
# 21_141.tif array written
# 21_219.tif array written
# 21_225.tif array written
# 21_15.tif array written
# 21_233.tif array written
# 21_23.tif array written
# 21_81.tif array written
# 21_185.tif array written
# 21_103.tif array written
# 21_191.tif array written
# 21_187.tif array written
# 21_7.tif array written
# 21_223.tif array written
# 21_39.tif array written
# 21_35.tif array written
# 21_75.tif array written
# 21_83.tif array written
# 21_105.tif array written
# 21_143.tif array written
# 21_221.tif array written
# 1_11.tif array written
# 1_51.tif array written
# 1_87.tif array written
# 1_101.tif array written
# 1_129.tif array written
# 1_63.tif array written
# 1_95.tif array written
# 1_59.tif array written
# 1_15.tif array written
# 1_117.tif array written
# 1_31.tif array written
# 1_127.tif array written
# 1_67.tif array written
# 5_29.tif array written
# 5_33.tif array written
# 5_47.tif array written
# 5_83.tif array written
# 5_73.tif array written
# 5_115.tif array written
# 5_149.tif array written
# 13_167.tif array written
# 13_235.tif array written
# 13_43.tif array written
# 13_103.tif array written
# 13_107.tif array written
# 13_125.tif array written
# 13_31.tif array written
# 13_119.tif array written
# 13_251.tif array written
# 13_15.tif array written
# 13_115.tif array written
# 13_213.tif array written
# 13_81.tif array written
# 13_93.tif array written
# 13_195.tif array written
# 13_287.tif array written
# 13_185.tif array written
# 13_315.tif array written
# 13_321.tif array written
# 13_5.tif array written
# 13_183.tif array written
# 13_61.tif array written
# 13_201.tif array written
# 13_305.tif array written
# 13_261.tif array written
# 13_243.tif array written
# 13_171.tif array written
# 17_65.tif array written
# 17_47.tif array written
# 17_165.tif array written
# 17_77.tif array written
# 18_123.tif array written
# 18_125.tif array written
# 19_129.tif array written
# 19_173.tif array written
# 18_101.tif array written
# 20_167.tif array written
# 20_17.tif array written
# 20_31.tif array written
# 20_177.tif array written
# 20_123.tif array written
# 20_43.tif array written
# 20_163.tif array written
# 20_65.tif array written
# 20_137.tif array written
# 20_95.tif array written
# 20_145.tif array written
# 20_1.tif array written
# 20_7.tif array written
# 20_37.tif array written
# 20_205.tif array written
# 20_207.tif array written
# 20_69.tif array written
# 20_175.tif array written
# 20_81.tif array written
# 21_5.tif array written
# 21_79.tif array written
# 21_97.tif array written
# 21_53.tif array written
# 21_65.tif array written
# 21_125.tif array written
# 21_177.tif array written
# 21_157.tif array written
# 21_145.tif array written
# 1_91.tif array written
# 1_35.tif array written
# 1_1.tif array written
# 1_41.tif array written
# 5_131.tif array written
# 5_119.tif array written
# 13_153.tif array written
# 13_75.tif array written
# 13_177.tif array written
# 17_93.tif array written
# 17_181.tif array written
# 20_105.tif array written
# 13_151.tif array written
# 20_197.tif array written
# 20_29.tif array written
# 20_161.tif array written
# 20_193.tif array written
# 20_97.tif array written
# 20_151.tif array written
# 20_185.tif array written
# 20_189.tif array written
# 20_57.tif array written
# 21_111.tif array written
# 21_41.tif array written
# 1_75.tif array written
# 13_209.tif array written
# 21_107.tif array written
# 13_303.tif array written
# 13_233.tif array written
# 18_13.tif array written
# 18_25.tif array written
# 20_91.tif array written
# 20_153.tif array written
# 20_179.tif array written
# 20_47.tif array written
# 20_55.tif array written
# 21_197.tif array written
# 21_203.tif array written
# 21_139.tif array written
# 5_81.tif array written
# 13_313.tif array written
# 13_155.tif array written
# 20_51.tif array written
# 20_53.tif array written
# 17_3.tif array written
# 20_101.tif array written
# 21_77.tif array written
# 1_107.tif array written
# 13_309.tif array written
# 5_91.tif array written
# 13_173.tif array written
# 20_209.tif array written
# 20_195.tif array written
# 1_97.tif array written
# 20_203.tif array written
# 13_37.tif array written
# 20_33.tif array written
# 5_45.tif array written
# 5_71.tif array written
# 12_79.tif array written
# 12_59.tif array written
# 12_33.tif array written
# 12_113.tif array written
# 21_173.tif array written
# 1_93.tif array written
# 12_63.tif array written
# 13_17.tif array written
# 17_31.tif array written
# 17_43.tif array written
# 20_71.tif array written
# 20_25.tif array written
# 20_109.tif array written
# 20_135.tif array written
# 12_121.tif array written
# 12_13.tif array written
# 12_39.tif array written
# 12_65.tif array written
# 12_133.tif array written
# 13_21.tif array written
# 13_283.tif array written
# 13_301.tif array written
# 13_29.tif array written
# 13_95.tif array written
# 13_307.tif array written
# 13_249.tif array written
# 20_67.tif array written
# 5_19.tif array written
# 13_3.tif array written
# 20_199.tif array written
# 20_93.tif array written
# 22_9.tif array written
# 22_25.tif array written
# 22_29.tif array written
# 22_39.tif array written
# 22_43.tif array written
# 22_77.tif array written
# 22_97.tif array written
# 22_117.tif array written
# 22_79.tif array written
# 22_73.tif array written
# 22_35.tif array written
# 22_65.tif array written
# 22_41.tif array written
# 22_83.tif array written
# 22_67.tif array written
# 22_123.tif array written
# 22_15.tif array written
# 22_17.tif array written
# 22_107.tif array written
# 22_45.tif array written
# 22_47.tif array written
# 22_101.tif array written
# 22_93.tif array written
# 22_1.tif array written
# 22_3.tif array written
# 22_99.tif array written
# 22_19.tif array written
# 22_53.tif array written
# 22_113.tif array written
# 24_19.tif array written
# 22_69.tif array written
# 24_45.tif array written
# 24_39.tif array written
# 24_47.tif array written
# 24_13.tif array written
# 24_21.tif array written
# 24_5.tif array written
# 24_25.tif array written
# 24_31.tif array written
# 24_3.tif array written
# 24_9.tif array written
# 24_17.tif array written
# 24_37.tif array written
# 24_11.tif array written
# 24_29.tif array written
# 24_35.tif array written
# 24_33.tif array written
# 26_51.tif array written
# 26_57.tif array written
# 26_107.tif array written
# 26_73.tif array written
# 26_111.tif array written
# 26_117.tif array written
# 26_11.tif array written
# 26_17.tif array written
# 26_63.tif array written
# 26_145.tif array written
# 26_151.tif array written
# 26_157.tif array written
# 26_15.tif array written
# 26_23.tif array written
# 26_25.tif array written
# 26_37.tif array written
# 26_59.tif array written
# 26_65.tif array written
# 26_45.tif array written
# 26_67.tif array written
# 26_75.tif array written
# 26_155.tif array written
# 26_149.tif array written
# 26_87.tif array written
# 26_91.tif array written
# 26_49.tif array written
# 26_93.tif array written
# 26_99.tif array written
# 26_115.tif array written
# 26_125.tif array written
# 26_147.tif array written
# 26_161.tif array written
# 26_163.tif array written
# 26_5.tif array written
# 26_27.tif array written
# 26_77.tif array written
# 26_81.tif array written
# 26_105.tif array written
# 26_121.tif array written
# 26_123.tif array written
# 27_9.tif array written
# 27_19.tif array written
# 27_85.tif array written
# 27_67.tif array written
# 27_97.tif array written
# 27_129.tif array written
# 27_139.tif array written
# 27_93.tif array written
# 27_143.tif array written
# 27_153.tif array written
# 27_145.tif array written
# 27_171.tif array written
# 27_3.tif array written
# 27_25.tif array written
# 27_53.tif array written
# 27_59.tif array written
# 27_1.tif array written
# 27_95.tif array written
# 27_163.tif array written
# 27_115.tif array written
# 27_27.tif array written
# 27_69.tif array written
# 27_87.tif array written
# 27_89.tif array written
# 27_113.tif array written
# 27_107.tif array written
# 27_119.tif array written
# 27_125.tif array written
# 27_13.tif array written
# 27_135.tif array written
# 27_15.tif array written
# 27_43.tif array written
# 27_47.tif array written
# 27_91.tif array written
# 27_79.tif array written
# 27_103.tif array written
# 27_131.tif array written
# 27_147.tif array written
# 27_161.tif array written
# 27_165.tif array written
# 27_37.tif array written
# 27_39.tif array written
# 27_45.tif array written
# 27_49.tif array written
# 27_99.tif array written
# 27_109.tif array written
# 27_33.tif array written
# 27_63.tif array written
# 27_83.tif array written
# 27_169.tif array written
# 27_101.tif array written
# 27_105.tif array written
# 27_133.tif array written
# 27_127.tif array written
# 27_23.tif array written
# 27_41.tif array written
# 27_51.tif array written
# 27_11.tif array written
# 27_73.tif array written
# 27_121.tif array written
# 27_149.tif array written
# 27_111.tif array written
# 27_155.tif array written
# 27_151.tif array written
# 27_173.tif array written
# 28_7.tif array written
# 28_15.tif array written
# 27_167.tif array written
# 28_51.tif array written
# 28_89.tif array written
# 28_97.tif array written
# 28_121.tif array written
# 28_123.tif array written
# 28_155.tif array written
# 28_17.tif array written

# %%
files_names.index('48_215.tif')
# Out:
# 997

# %%
files_names[998:]
# Out:
# ['48_215.tif',
#  '1_47.tif',
#  '1_65.tif',
#  '1_85.tif',
#  '1_105.tif',
#  '1_119.tif',
#  '1_3.tif',
#  '1_53.tif',
#  '1_99.tif',
#  '1_9.tif',
#  '1_19.tif',
#  '1_43.tif',
#  '1_49.tif',
#  '1_55.tif',
#  '1_71.tif',
#  '1_33.tif',
#  '1_77.tif',
#  '1_79.tif',
#  '1_83.tif',
