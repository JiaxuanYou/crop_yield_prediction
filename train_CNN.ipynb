# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import sys

# Note: may have to append or delete "/" after prediction_models and re-run.
sys.path.append("/content/drive/My Drive/CropYield/prediction_models/")

# %%
from pathlib import Path

import CNN

save_dir  = Path("/content/drive/My Drive/CropYield/trained_models")
histogram = Path("/content/drive/My Drive/CropYield/histogram_all_full.npz")

pred_years = range(2009, 2019)

cnn = CNN.ConvModel(savedir=save_dir)
cnn.run(path_to_histogram=histogram, pred_years=pred_years, patience=10)
